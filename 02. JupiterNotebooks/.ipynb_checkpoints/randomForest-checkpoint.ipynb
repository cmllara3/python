# %% [markdown]
# # Random Forest Exercise
# Predecir la temperatura de mañana

# %% [markdown]
# ### 1. Librerías

# %%
#Importacion de la Libreria pandas
import pandas as pd
#Importacion de la libreria numpy
import numpy as np

# %% [markdown]
# ### 2. Leer fichero

# %%
temp = pd.read_csv("../01. Flat Files/temps.csv")
temp.head()
# Out:
#    year  month  day  week  temp_2  temp_1  average  actual  forecast_noaa  \
# 0  2016      1    1   Fri      45      45     45.6      45             43
# 1  2016      1    2   Sat      44      45     45.7      44             41
# 2  2016      1    3   Sun      45      44     45.8      41             43
# 3  2016      1    4   Mon      44      41     45.9      40             44
# 4  2016      1    5  Tues      41      40     46.0      44             46
#
#    forecast_acc  forecast_under  friend
# 0            50              44      29
# 1            50              44      61
# 2            46              47      56
# 3            48              46      53
# 4            46              46      41

# %% [markdown]
# ### 3. Transformar campo nominal a numérico
# One Hot encoding

# %%
#dictWeek = {"Fri":5,"Mon":1,"Sat":6,"Sun":7,"Thurs":4,"Tues":2,"Wed":3}
#temp["week"] = temp["week"].replace(dictWeek)
#temp.head()

dfDummiesWeek = pd.get_dummies(temp["week"])

temp = pd.concat([temp,dfDummiesWeek],axis=1)
temp.head()

temp = temp.drop(columns={"week"})
temp.head()
# Out:
#    year  month  day  temp_2  temp_1  average  actual  forecast_noaa  \
# 0  2016      1    1      45      45     45.6      45             43
# 1  2016      1    2      44      45     45.7      44             41
# 2  2016      1    3      45      44     45.8      41             43
# 3  2016      1    4      44      41     45.9      40             44
# 4  2016      1    5      41      40     46.0      44             46
#
#    forecast_acc  forecast_under  friend  Fri  Mon  Sat  Sun  Thurs  Tues  Wed
# 0            50              44      29    1    0    0    0      0     0    0
# 1            50              44      61    0    0    1    0      0     0    0
# 2            46              47      56    0    0    0    1      0     0    0
# 3            48              46      53    0    1    0    0      0     0    0
# 4            46              46      41    0    0    0    0      0     1    0

# %% [markdown]
# ### 4. Identificación de "label"

# %%
x = temp.drop(columns={"actual"})
y = temp["actual"]

# %% [markdown]
# ### 5. Datos de Training and Testing

# %%
from sklearn.model_selection import train_test_split

xTrain, xTest, yTrain, yTest = train_test_split(x,y,test_size=0.3,random_state=101)

# %% [markdown]
# ### 6. Tomamos una referencia de error con la media histórica

# %%
yPredict1 = x["average"]
errores = abs(y-yPredict1)
print("Error con la media historica: ",errores.mean())
del errores,yPredict1
# Out:
# Error con la media historica:  4.933045977011492

# %% [markdown]
# ### 7. Entrenamos el Forest

# %% [markdown]
# Podemos probar con otros parámetros!

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()

rfr.fit(xTrain,yTrain)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# ### 8. Predicciones sobre los datos Test

# %%
yPredict = rfr.predict(xTest)
# Out:
#      year  month  day  temp_2  temp_1  average  forecast_noaa  forecast_acc  \
# 0    2016      1    1      45      45     45.6             43            50
# 1    2016      1    2      44      45     45.7             41            50
# 2    2016      1    3      45      44     45.8             43            46
# 3    2016      1    4      44      41     45.9             44            48
# 4    2016      1    5      41      40     46.0             46            46
# ..    ...    ...  ...     ...     ...      ...            ...           ...
# 343  2016     12   27      42      42     45.2             41            50
# 344  2016     12   28      42      47     45.3             41            49
# 345  2016     12   29      47      48     45.3             43            50
# 346  2016     12   30      48      48     45.4             44            46
# 347  2016     12   31      48      57     45.5             42            48
#
#      forecast_under  friend  Fri  Mon  Sat  Sun  Thurs  Tues  Wed
# 0                44      29    1    0    0    0      0     0    0
# 1                44      61    0    0    1    0      0     0    0
# 2                47      56    0    0    0    1      0     0    0
# 3                46      53    0    1    0    0      0     0    0
# 4                46      41    0    0    0    0      0     1    0
# ..              ...     ...  ...  ...  ...  ...    ...   ...  ...
# 343              47      47    0    0    0    0      0     1    0
# 344              44      58    0    0    0    0      0     0    1
# 345              45      65    0    0    0    0      1     0    0
# 346              44      42    1    0    0    0      0     0    0
# 347              47      57    0    0    1    0      0     0    0
#
# [348 rows x 17 columns]

# %% [markdown]
# ### 9. Visualización del árbol

# %%
from sklearn.tree import export_graphviz

arbol = rfr.estimators_[5] 

export_graphviz(arbol,out_file='tree_nonlimited.dot',feature_names = list(x.columns),rounded = True, 
                proportion = False,precision = 2,filled = True)

import pydot 

pydot.graph_from_dot_file('tree_nonlimited.dot').write_png('tree_nonlimited.png')

# Display in jupyter notebook
from IPython.display import Image
Image(filename = 'tree_nonlimited.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-7d8bc622e5a3> in <module>()
#       7
#       8 from subprocess import call
# ----> 9 call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png'])
#      10
#      11 # Display in jupyter notebook
#
# C:\Users\USUARIO\Anaconda3\lib\subprocess.py in call(timeout, *popenargs, **kwargs)
#     337     retcode = call(["ls", "-l"])
#     338     """
# --> 339     with Popen(*popenargs, **kwargs) as p:
#     340         try:
#     341             return p.wait(timeout=timeout)
#
# C:\Users\USUARIO\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     798                                 c2pread, c2pwrite,
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#     802             # Cleanup if the child failed starting.
#
# C:\Users\USUARIO\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1205                                          env,
#    1206                                          os.fspath(cwd) if cwd is not None else None,
# -> 1207                                          startupinfo)
#    1208             finally:
#    1209                 # Child is launched. Close the parent's copy of those pipe
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %% [markdown]
# ### 10. Importancia de las variables

# %% [markdown]
# ### 11. Nuevo modelo con los dos inputs más importantes

# %% [markdown]
# ### 12. Visualizaciones
